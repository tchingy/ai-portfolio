# %% [markdown]
# <a href="https://colab.research.google.com/github/tchingy/ai-portfolio/blob/main/hvac_sentiment_analyser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datasets import load_dataset
ds = load_dataset("vitaliy-sharandin/energy-consumption-hourly-spain")
print(ds["train"][0])

# %%
# =============================================
# DATASET UNDERSTANDING — Task 4 Notes
# =============================================

# 1. WHAT IS THIS DATASET?
# Real hourly energy data from Spain's national grid, 2015–2018.
# 35,064 rows — one per hour — covering generation, consumption, forecasts and prices.

# 2. WHAT COLUMNS DOES IT CONTAIN?
# 29 columns in 4 groups: timestamp, generation (MW per source),
# forecasts (day-ahead predictions), and prices (EUR/MWh).

# 3. WHAT DOES ONE ROW REPRESENT?
# One complete hour of Spain's electricity system —
# every source, total load, forecasts and prices at the same moment.

# 4. MISSING DATA?
# Two columns contain None (null) values — hydro pumped storage aggregated
# and wind offshore forecast. Would need to be filled or removed before AI training.

# 5. WHAT COULD AN AI MODEL PREDICT?
# Future electricity prices, next-hour grid load, solar/wind generation forecasts.
# Closing the gap between forecast and actual values is a key commercial AI use case.
